# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rbernalc/pytorch-mx/blob/main/tutorials/basic/colab_setup.ipynb)

# %% [markdown]
# ### Clonar el repositorio

# %%
# !git clone https://github.com/rbernalc/pytorch-mx.git

# %% [markdown]
# ### Cambia al directorio de tutoriales basicos

# %%
import os
LAB_PATH ='pytorch-mx/tutorials/basic'
os.chdir(LAB_PATH)
# !ls

# %% [markdown]
# ### Instalacion de paquetes adicionales

# %% [markdown]
# !pip install matplotlib
